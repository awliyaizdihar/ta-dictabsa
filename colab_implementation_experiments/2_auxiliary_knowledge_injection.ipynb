# %% [markdown]
# # Import Library

# %%
# Import Library Python
import pandas as pd

# %% [markdown]
# # Load Dataset

# %% [markdown]
# ## Dataset Ulasan

# %%
file_train = f'https://docs.google.com/spreadsheets/d/17CTFM7JGIFJVVaKzMx3ffm9OfbDXqGY5/gviz/tq?tqx=out:csv'
file_test = f'https://docs.google.com/spreadsheets/d/15vGpggHH_uyprLH2cM1RCTfRGLttzKuu/gviz/tq?tqx=out:csv'
file_validation = f'https://docs.google.com/spreadsheets/d/1QjmHbXVURLoYQafheq6buuy4vC9egGnG/gviz/tq?tqx=out:csv'
train_set = pd.read_csv(file_train)
test_set = pd.read_csv(file_test)
validation_set = pd.read_csv(file_validation)

# %%
train_set.head()
# Out:
#                                               review            aspect  \
# 0  [B-ASP]tempat[E-ASP] yang sakral sekali dibali...            tempat
# 1  tempat yang sakral sekali dibali setelah pura ...            lokasi
# 2  tempat yang sakral sekali dibali setelah pura ...            lokasi
# 3  ini tempat [B-ASP]taman wisata air[E-ASP] pali...  taman wisata air
# 4  ini adalah [B-ASP]pengalaman[E-ASP] yang luar ...        pengalaman
#
#    sentiment
# 0          0
# 1         -1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ## Dataset All Knowledge

# %%
file_know = f'https://docs.google.com/spreadsheets/d/1ysks_5UHePOpViY2qghotY-xqig3BO-pEIkFtkrbCR0/gviz/tq?tqx=out:csv'
know_set = pd.read_csv(file_know, usecols=['aspect', 'knowledge'])
know_set
# Out:
#            aspect                                          knowledge
# 0          tempat  sesuatu yang dipakai untuk menaruh (menyimpan,...
# 1          lokasi                                 letak [SEP] tempat
# 2    taman wisata  hutan wisata yang memiliki keindahan alam, bai...
# 3      pengalaman  yang pernah dialami (dirasai, dijalani, ditang...
# 4           hotel  bangunan berkamar banyak yang disewakan sebaga...
# ..            ...                                                ...
# 857    musim sepi  suatu waktu dalam setahun ketika jumlah pengun...
# 858      pengawas  orang yang mengawasi [SEP] peranti yang mengon...
# 859   pintu masuk                      pintu yang khusus untuk masuk
# 860      pedesaan                                          perdesaan
# 861    pegunungan                                        pergunungan
#
# [862 rows x 2 columns]

# %% [markdown]
# # Dataset Pre-processing

# %% [markdown]
# ## Mengekstrak Data
#
# Dataset masih berupa kumpulan ulasan dari peneliti sebelumnya.
#
# Data tersebut akan diekstrak menjadi dataset dengan 3 kolom (review, aspect, dan sentiment).

# %%
test_str = train_set.review[1]
test_str
# Out:
# 'tempat yang sakral sekali dibali setelah pura uluwatu.. belum lengkap kebali kalau belum kesini, meski [B-ASP]lokasi[E-ASP] lumayan jauh tapi lokasi ini pelengkap kalau kebali.. $LABEL$ Negative'

# %% [markdown]
# ### Mengekstrak Aspek
#
# Aspek dalam ulasan diapit di antara tanda [B-ASP] dan [E-ASP].

# %%
datasets = [train_set, validation_set, test_set]

# %%
# menginisialisasi substring
b_asp = "[B-ASP]"
e_asp = "[E-ASP]"

# mengambil kata aspek di antara 2 substring menggunakan split() dan join()
for sets in datasets:
  sets['aspect'] = sets.review.apply(lambda x: ''.join(x.split(b_asp)[1].split(e_asp)[0]))

# %%
train_set
# Out:
#                                                  review              aspect
# 0     [B-ASP]tempat[E-ASP] yang sakral sekali dibali...              tempat
# 1     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 2     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 3     ini tempat [B-ASP]taman wisata air[E-ASP] pali...    taman wisata air
# 4     ini adalah [B-ASP]pengalaman[E-ASP] yang luar ...          pengalaman
# ...                                                 ...                 ...
# 5625  di [B-ASP]pura luhur uluwatu[E-ASP] dengan pem...  pura luhur uluwatu
# 5626  di pura luhur uluwatu dengan pemandangan lepas...             uluwatu
# 5627  di pura luhur uluwatu dengan pemandangan lepas...              tempat
# 5628  di pura luhur uluwatu dengan pemandangan lepas...              wisata
# 5629  di pura luhur uluwatu dengan pemandangan lepas...              tempat
#
# [5630 rows x 2 columns]

# %%
validation_set
# Out:
#                                                  review            aspect
# 0     [B-ASP]jalan pagi[E-ASP] menyusuri campuhan ri...        jalan pagi
# 1     jalan pagi menyusuri [B-ASP]campuhan ridge[E-A...    campuhan ridge
# 2     jalan pagi menyusuri campuhan ridge merupakan ...            tangga
# 3     jalan pagi menyusuri campuhan ridge merupakan ...       jalur tanah
# 4     jalan pagi menyusuri campuhan ridge merupakan ...             jalur
# ...                                                 ...               ...
# 1167  tanah lot, [B-ASP]pemandangannya[E-ASP] kerap ...    pemandangannya
# 1168  tanah lot, pemandangannya kerap kita lihat di ...  pemandangan laut
# 1169  tanah lot, pemandangannya kerap kita lihat di ...            sunset
# 1170  tanah lot, pemandangannya kerap kita lihat di ...             ombak
# 1171  tanah lot, pemandangannya kerap kita lihat di ...       pemandangan
#
# [1172 rows x 2 columns]

# %%
test_set
# Out:
#                                                  review          aspect
# 0     salah satu [B-ASP]pantai[E-ASP] terbaik di bal...          pantai
# 1     salah satu pantai terbaik di bali, di mana and...        keluarga
# 2     salah satu pantai terbaik di bali, di mana and...           hotel
# 3     salah satu pantai terbaik di bali, di mana and...   kursi pribadi
# 4     salah satu pantai terbaik di bali, di mana and...            tamu
# ...                                                 ...             ...
# 1183  pemandangan yang sangat sangat menawan, kombin...           tiket
# 1184  pemandangan yang sangat sangat menawan, kombin...          parkir
# 1185  dinner with the [B-ASP]great elephant[E-ASP] a...  great elephant
# 1186  dinner with the great elephant adalah salah sa...         program
# 1187  [B-ASP]dinner[E-ASP] with the great elephant a...          dinner
#
# [1188 rows x 2 columns]

# %% [markdown]
# ### Mengekstrak Sentimen
#
# Polaritas sentimen terletak di akhir kalimat ulasan.

# %%
for sets in datasets:
  new = sets['review'].str.split(pat=" $LABEL$ ", n=1, expand=True, regex=False)
  sets['review'] = new[0]
  sets['sentiment'] = new[1]

# %%
train_set
# Out:
#                                                  review              aspect  \
# 0     [B-ASP]tempat[E-ASP] yang sakral sekali dibali...              tempat
# 1     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 2     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 3     ini tempat [B-ASP]taman wisata air[E-ASP] pali...    taman wisata air
# 4     ini adalah [B-ASP]pengalaman[E-ASP] yang luar ...          pengalaman
# ...                                                 ...                 ...
# 5625  di [B-ASP]pura luhur uluwatu[E-ASP] dengan pem...  pura luhur uluwatu
# 5626  di pura luhur uluwatu dengan pemandangan lepas...             uluwatu
# 5627  di pura luhur uluwatu dengan pemandangan lepas...              tempat
# 5628  di pura luhur uluwatu dengan pemandangan lepas...              wisata
# 5629  di pura luhur uluwatu dengan pemandangan lepas...              tempat
#
#      sentiment
# 0      Neutral
# 1     Negative
# ...

# %%
validation_set
# Out:
#                                                  review            aspect  \
# 0     [B-ASP]jalan pagi[E-ASP] menyusuri campuhan ri...        jalan pagi
# 1     jalan pagi menyusuri [B-ASP]campuhan ridge[E-A...    campuhan ridge
# 2     jalan pagi menyusuri campuhan ridge merupakan ...            tangga
# 3     jalan pagi menyusuri campuhan ridge merupakan ...       jalur tanah
# 4     jalan pagi menyusuri campuhan ridge merupakan ...             jalur
# ...                                                 ...               ...
# 1167  tanah lot, [B-ASP]pemandangannya[E-ASP] kerap ...    pemandangannya
# 1168  tanah lot, pemandangannya kerap kita lihat di ...  pemandangan laut
# 1169  tanah lot, pemandangannya kerap kita lihat di ...            sunset
# 1170  tanah lot, pemandangannya kerap kita lihat di ...             ombak
# 1171  tanah lot, pemandangannya kerap kita lihat di ...       pemandangan
#
#      sentiment
# 0     Positive
# 1      Neutral
# 2     Negative
# ...

# %%
test_set
# Out:
#                                                  review          aspect  \
# 0     salah satu [B-ASP]pantai[E-ASP] terbaik di bal...          pantai
# 1     salah satu pantai terbaik di bali, di mana and...        keluarga
# 2     salah satu pantai terbaik di bali, di mana and...           hotel
# 3     salah satu pantai terbaik di bali, di mana and...   kursi pribadi
# 4     salah satu pantai terbaik di bali, di mana and...            tamu
# ...                                                 ...             ...
# 1183  pemandangan yang sangat sangat menawan, kombin...           tiket
# 1184  pemandangan yang sangat sangat menawan, kombin...          parkir
# 1185  dinner with the [B-ASP]great elephant[E-ASP] a...  great elephant
# 1186  dinner with the great elephant adalah salah sa...         program
# 1187  [B-ASP]dinner[E-ASP] with the great elephant a...          dinner
#
#      sentiment
# 0     Positive
# 1      Neutral
# 2     Negative
# 3     Negative
# 4      Neutral
# ...

# %% [markdown]
# ## Praproses Data

# %% [markdown]
# ### Encoding Label Sentimen
#
# Mengubah label sentimen yang berupa kata (Positive, Neutral, Negative) menjadi angka (1, 0, -1).

# %%
# mengubah label sentimen manjadi angka
for sets in datasets:
  sets.replace({'sentiment' : {'Positive': 1 , 'Neutral': 0, 'Negative':-1}}, inplace=True)

# %%
train_set
# Out:
#                                                  review              aspect  \
# 0     [B-ASP]tempat[E-ASP] yang sakral sekali dibali...              tempat
# 1     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 2     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 3     ini tempat [B-ASP]taman wisata air[E-ASP] pali...    taman wisata air
# 4     ini adalah [B-ASP]pengalaman[E-ASP] yang luar ...          pengalaman
# ...                                                 ...                 ...
# 5625  di [B-ASP]pura luhur uluwatu[E-ASP] dengan pem...  pura luhur uluwatu
# 5626  di pura luhur uluwatu dengan pemandangan lepas...             uluwatu
# 5627  di pura luhur uluwatu dengan pemandangan lepas...              tempat
# 5628  di pura luhur uluwatu dengan pemandangan lepas...              wisata
# 5629  di pura luhur uluwatu dengan pemandangan lepas...              tempat
#
#       sentiment
# 0             0
# 1            -1
# ...

# %%
validation_set
# Out:
#                                                  review            aspect  \
# 0     [B-ASP]jalan pagi[E-ASP] menyusuri campuhan ri...        jalan pagi
# 1     jalan pagi menyusuri [B-ASP]campuhan ridge[E-A...    campuhan ridge
# 2     jalan pagi menyusuri campuhan ridge merupakan ...            tangga
# 3     jalan pagi menyusuri campuhan ridge merupakan ...       jalur tanah
# 4     jalan pagi menyusuri campuhan ridge merupakan ...             jalur
# ...                                                 ...               ...
# 1167  tanah lot, [B-ASP]pemandangannya[E-ASP] kerap ...    pemandangannya
# 1168  tanah lot, pemandangannya kerap kita lihat di ...  pemandangan laut
# 1169  tanah lot, pemandangannya kerap kita lihat di ...            sunset
# 1170  tanah lot, pemandangannya kerap kita lihat di ...             ombak
# 1171  tanah lot, pemandangannya kerap kita lihat di ...       pemandangan
#
#       sentiment
# 0             1
# 1             0
# 2            -1
# ...

# %%
test_set
# Out:
#                                                  review          aspect  \
# 0     salah satu [B-ASP]pantai[E-ASP] terbaik di bal...          pantai
# 1     salah satu pantai terbaik di bali, di mana and...        keluarga
# 2     salah satu pantai terbaik di bali, di mana and...           hotel
# 3     salah satu pantai terbaik di bali, di mana and...   kursi pribadi
# 4     salah satu pantai terbaik di bali, di mana and...            tamu
# ...                                                 ...             ...
# 1183  pemandangan yang sangat sangat menawan, kombin...           tiket
# 1184  pemandangan yang sangat sangat menawan, kombin...          parkir
# 1185  dinner with the [B-ASP]great elephant[E-ASP] a...  great elephant
# 1186  dinner with the great elephant adalah salah sa...         program
# 1187  [B-ASP]dinner[E-ASP] with the great elephant a...          dinner
#
#       sentiment
# 0             1
# 1             0
# 2            -1
# 3            -1
# ...

# %% [markdown]
# ### Normalisasi Kata Aspek

# %% [markdown]
# Mengembalikan aspek ke kata dasar. (Contoh: "pemandangannya" ==> "pemandangan")

# %%
# menghapus imbuhan -nya pada kata aspek
for sets in datasets:
  sets['aspect'] = sets['aspect'].str.replace("nya$", "", regex=True)

# %% [markdown]
# # Knowledge Injection

# %% [markdown]
# ## Inserting Knowledge

# %%
train_set.head()
# Out:
#                                               review            aspect  \
# 0  [B-ASP]tempat[E-ASP] yang sakral sekali dibali...            tempat
# 1  tempat yang sakral sekali dibali setelah pura ...            lokasi
# 2  tempat yang sakral sekali dibali setelah pura ...            lokasi
# 3  ini tempat [B-ASP]taman wisata air[E-ASP] pali...  taman wisata air
# 4  ini adalah [B-ASP]pengalaman[E-ASP] yang luar ...        pengalaman
#
#    sentiment
# 0          0
# 1         -1
# 2          1
# 3          1
# 4          1

# %%
def insert_know(dataset):
  dataset['before_knowledge'] = dataset.review.apply(lambda x: x[:x.find(b_asp)])
  dataset['after_knowledge'] = dataset.review.apply(lambda x: x[x.find(e_asp) + len(e_asp):])
  dataset['knowledge'] = ' $ ' + dataset['knowledge'] + ' $'
  dataset['review'] = dataset[['before_knowledge', 'aspect', 'knowledge', 'after_knowledge']].stack().groupby(level=0).agg(''.join)
  dataset.drop(columns=['before_knowledge', 'knowledge', 'after_knowledge'], inplace=True)

# %%
train_know = []
train_know = pd.merge(train_set, know_set, on='aspect', how='left')
insert_know(train_know)
train_know
# Out:
#                                                  review              aspect  \
# 0     tempat $ sesuatu yang dipakai untuk menaruh (m...              tempat
# 1     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 2     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 3     ini tempat taman wisata air paling lengkap di ...    taman wisata air
# 4     ini adalah pengalaman $ yang pernah dialami (d...          pengalaman
# ...                                                 ...                 ...
# 5625  di pura luhur uluwatu dengan pemandangan lepas...  pura luhur uluwatu
# 5626  di pura luhur uluwatu dengan pemandangan lepas...             uluwatu
# 5627  di pura luhur uluwatu dengan pemandangan lepas...              tempat
# 5628  di pura luhur uluwatu dengan pemandangan lepas...              wisata
# 5629  di pura luhur uluwatu dengan pemandangan lepas...              tempat
#
#       sentiment
# 0             0
# 1            -1
# ...

# %%
validation_know = []
validation_know = pd.merge(validation_set, know_set, on='aspect', how='left')
insert_know(validation_know)
validation_know
# Out:
#                                                  review            aspect  \
# 0     jalan pagi menyusuri campuhan ridge merupakan ...        jalan pagi
# 1     jalan pagi menyusuri campuhan ridge merupakan ...    campuhan ridge
# 2     jalan pagi menyusuri campuhan ridge merupakan ...            tangga
# 3     jalan pagi menyusuri campuhan ridge merupakan ...       jalur tanah
# 4     jalan pagi menyusuri campuhan ridge merupakan ...             jalur
# ...                                                 ...               ...
# 1167  tanah lot, pemandangan $ penglihatan [SEP] pro...       pemandangan
# 1168  tanah lot, pemandangannya kerap kita lihat di ...  pemandangan laut
# 1169  tanah lot, pemandangannya kerap kita lihat di ...            sunset
# 1170  tanah lot, pemandangannya kerap kita lihat di ...             ombak
# 1171  tanah lot, pemandangannya kerap kita lihat di ...       pemandangan
#
#       sentiment
# 0             1
# 1             0
# 2            -1
# ...

# %%
test_know = []
test_know = pd.merge(test_set, know_set, on='aspect', how='left')
insert_know(test_know)
test_know
# Out:
#                                                  review          aspect  \
# 0     salah satu pantai $ tepi laut [SEP] perbatasan...          pantai
# 1     salah satu pantai terbaik di bali, di mana and...        keluarga
# 2     salah satu pantai terbaik di bali, di mana and...           hotel
# 3     salah satu pantai terbaik di bali, di mana and...   kursi pribadi
# 4     salah satu pantai terbaik di bali, di mana and...            tamu
# ...                                                 ...             ...
# 1183  pemandangan yang sangat sangat menawan, kombin...           tiket
# 1184  pemandangan yang sangat sangat menawan, kombin...          parkir
# 1185  dinner with the great elephant adalah salah sa...  great elephant
# 1186  dinner with the great elephant adalah salah sa...         program
# 1187  dinner with the great elephant adalah salah sa...          dinner
#
#       sentiment
# 0             1
# 1             0
# 2            -1
# 3            -1
# ...

# %% [markdown]
# ## Concatenating Knowledge

# %% [markdown]
# Menghapus penanda posisi aspek yang sudah tidak terpakai

# %%
train_set.head()
# Out:
#                                               review            aspect  \
# 0  [B-ASP]tempat[E-ASP] yang sakral sekali dibali...            tempat
# 1  tempat yang sakral sekali dibali setelah pura ...            lokasi
# 2  tempat yang sakral sekali dibali setelah pura ...            lokasi
# 3  ini tempat [B-ASP]taman wisata air[E-ASP] pali...  taman wisata air
# 4  ini adalah [B-ASP]pengalaman[E-ASP] yang luar ...        pengalaman
#
#    sentiment
# 0          0
# 1         -1
# 2          1
# 3          1
# 4          1

# %%
# menghapus tanda aspek yang sudah tidak terpakai
for sets in datasets:
  sets['review'] = sets['review'].str.replace(b_asp, "", regex=False)
  sets['review'] = sets['review'].str.replace(e_asp, "", regex=False)

# %% [markdown]
# Concatenating Knowledge

# %%
train_concat = []
train_concat = pd.merge(train_set, know_set, on='aspect', how='left')
train_concat['review'] = train_concat[['review', 'knowledge']].stack().groupby(level=0).agg(' [SEP] '.join)
train_concat.drop(columns=['knowledge'], inplace=True)
train_concat
# Out:
#                                                  review              aspect  \
# 0     tempat yang sakral sekali dibali setelah pura ...              tempat
# 1     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 2     tempat yang sakral sekali dibali setelah pura ...              lokasi
# 3     ini tempat taman wisata air paling lengkap di ...    taman wisata air
# 4     ini adalah pengalaman yang luar biasa. hotel m...          pengalaman
# ...                                                 ...                 ...
# 5625  di pura luhur uluwatu dengan pemandangan lepas...  pura luhur uluwatu
# 5626  di pura luhur uluwatu dengan pemandangan lepas...             uluwatu
# 5627  di pura luhur uluwatu dengan pemandangan lepas...              tempat
# 5628  di pura luhur uluwatu dengan pemandangan lepas...              wisata
# 5629  di pura luhur uluwatu dengan pemandangan lepas...              tempat
#
#       sentiment
# 0             0
# 1            -1
# ...

# %%
validation_concat = []
validation_concat = pd.merge(validation_set, know_set, on='aspect', how='left')
validation_concat['review'] = validation_concat[['review', 'knowledge']].stack().groupby(level=0).agg(' [SEP] '.join)
validation_concat.drop(columns=['knowledge'], inplace=True)
validation_concat
# Out:
#                                                  review            aspect  \
# 0     jalan pagi menyusuri campuhan ridge merupakan ...        jalan pagi
# 1     jalan pagi menyusuri campuhan ridge merupakan ...    campuhan ridge
# 2     jalan pagi menyusuri campuhan ridge merupakan ...            tangga
# 3     jalan pagi menyusuri campuhan ridge merupakan ...       jalur tanah
# 4     jalan pagi menyusuri campuhan ridge merupakan ...             jalur
# ...                                                 ...               ...
# 1167  tanah lot, pemandangannya kerap kita lihat di ...       pemandangan
# 1168  tanah lot, pemandangannya kerap kita lihat di ...  pemandangan laut
# 1169  tanah lot, pemandangannya kerap kita lihat di ...            sunset
# 1170  tanah lot, pemandangannya kerap kita lihat di ...             ombak
# 1171  tanah lot, pemandangannya kerap kita lihat di ...       pemandangan
#
#       sentiment
# 0             1
# 1             0
# 2            -1
# ...

# %%
test_concat = []
test_concat = pd.merge(test_set, know_set, on='aspect', how='left')
test_concat['review'] = test_concat[['review', 'knowledge']].stack().groupby(level=0).agg(' [SEP] '.join)
test_concat.drop(columns=['knowledge'], inplace=True)
test_concat
# Out:
#                                                  review          aspect  \
# 0     salah satu pantai terbaik di bali, di mana and...          pantai
# 1     salah satu pantai terbaik di bali, di mana and...        keluarga
# 2     salah satu pantai terbaik di bali, di mana and...           hotel
# 3     salah satu pantai terbaik di bali, di mana and...   kursi pribadi
# 4     salah satu pantai terbaik di bali, di mana and...            tamu
# ...                                                 ...             ...
# 1183  pemandangan yang sangat sangat menawan, kombin...           tiket
# 1184  pemandangan yang sangat sangat menawan, kombin...          parkir
# 1185  dinner with the great elephant adalah salah sa...  great elephant
# 1186  dinner with the great elephant adalah salah sa...         program
# 1187  dinner with the great elephant adalah salah sa...          dinner
#
#       sentiment
# 0             1
# 1             0
# 2            -1
# 3            -1
# ...
